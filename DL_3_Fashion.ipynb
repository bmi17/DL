# %% [markdown]
# # **Problem Statement:**

# %% [markdown]
# Convolutional neural network (CNN)
#
# Use MNIST Fashion Dataset and create a classifier to classify fashion clothing into
# categories.

# %% [markdown]
# About the dataset:
#
# Fashion-MNIST is a dataset of Zalando's article images—consisting of a training set of 60,000 examples and a test set of 10,000 examples. Each example is a 28x28 grayscale image, associated with a label from 10 classes. Zalando intends Fashion-MNIST to serve as a direct drop-in replacement for the original MNIST dataset for benchmarking machine learning algorithms. It shares the same image size and structure of training and testing splits.

# %% [markdown]
# Import the libraries

# %%
# TensorFlow and tf.keras
import tensorflow as tf

# Helper libraries
import numpy as np
import matplotlib.pyplot as plt

print(tf.__version__)
# Out:
# 2.12.0

# %% [markdown]
# # **Import the fashion MNIST dataset**

# %%
fashion_mnist = tf.keras.datasets.fashion_mnist

(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 0s 0us/step

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %% [markdown]
# # **EDA:**

# %% [markdown]
# Preprocessing of data:

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
len(train_labels)
# Out:
# 60000

# %%
train_labels
# Out:
# array([9, 0, 0, ..., 3, 0, 5], dtype=uint8)

# %%
test_images.shape
# Out:
# (10000, 28, 28)

# %%
len(test_labels)
# Out:
# 10000

# %% [markdown]
# # **Explore the data:**

# %%
plt.figure()
plt.imshow(train_images[0])
plt.colorbar()
plt.grid(False)
plt.show()

# %% [markdown]
# # **Feature Engineering:**

# %%
train_images = train_images / 255.0

test_images = test_images / 255.0

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[train_labels[i]])
plt.show()

# %% [markdown]
# # **Model Building/ training and testing:**

# %% [markdown]
# Build the model

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(10)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# Train the model

# %%
model.fit(train_images, train_labels, epochs=30)
# Out:
# Epoch 1/30
# 1875/1875 [==============================] - 15s 7ms/step - loss: 0.5085 - accuracy: 0.8219
# Epoch 2/30
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.3791 - accuracy: 0.8628
# Epoch 3/30
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3395 - accuracy: 0.8757
# Epoch 4/30
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3139 - accuracy: 0.8838
# Epoch 5/30
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2945 - accuracy: 0.8916
# Epoch 6/30
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2813 - accuracy: 0.8961
# Epoch 7/30
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2678 - accuracy: 0.9007
# Epoch 8/30
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.2583 - accuracy: 0.9038
# Epoch 9/30
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2480 - accuracy: 0.9082
# Epoch 10/30
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2400 - accuracy: 0.9107
# Epoch 11/30
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2331 - accuracy: 0.9132
# Epoch 12/30
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2263 - accuracy: 0.9144
# Epoch 13/30
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2169 - accuracy: 0.9191
# Epoch 14/30
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2136 - accuracy: 0.9204
# Epoch 15/30
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2060 - accuracy: 0.9230
# Epoch 16/30
# 1875/1875 [==============================] - 8s 5ms/step - loss: 0.2007 - accuracy: 0.9241
# Epoch 17/30
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.1943 - accuracy: 0.9256
# Epoch 18/30
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1907 - accuracy: 0.9277
# Epoch 19/30
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1840 - accuracy: 0.9312
# Epoch 20/30
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1789 - accuracy: 0.9326
# Epoch 21/30
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1746 - accuracy: 0.9343
# Epoch 22/30
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1737 - accuracy: 0.9349
# Epoch 23/30
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1669 - accuracy: 0.9362
# Epoch 24/30
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.1649 - accuracy: 0.9385
# Epoch 25/30
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1579 - accuracy: 0.9397
# Epoch 26/30
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1565 - accuracy: 0.9413
# Epoch 27/30
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1540 - accuracy: 0.9412
# Epoch 28/30
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1479 - accuracy: 0.9438
# Epoch 29/30
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1452 - accuracy: 0.9461
# Epoch 30/30
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1452 - accuracy: 0.9450

# %% [markdown]
# # **Model Evaluation:**

# %%
test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)

print('\nTest accuracy:', test_acc)
# Out:
# 313/313 - 1s - loss: 0.3934 - accuracy: 0.8841 - 611ms/epoch - 2ms/step
#
# Test accuracy: 0.8841000199317932

# %% [markdown]
# Make predictions

# %%
probability_model = tf.keras.Sequential([model, 
                                         tf.keras.layers.Softmax()])

# %%
predictions = probability_model.predict(test_images)
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %%
predictions[0]
# Out:
# array([2.8869574e-12, 3.4561906e-16, 2.9472121e-12, 8.1394738e-11,
#        1.7357633e-14, 4.0395474e-07, 8.2262148e-12, 2.4352519e-05,
#        8.1797156e-12, 9.9997514e-01], dtype=float32)

# %%
np.argmax(predictions[0])
# Out:
# 9

# %%
test_labels[0]
# Out:
# 9

# %%
def plot_image(i, predictions_array, true_label, img):
  true_label, img = true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(class_names[predicted_label],
                                100*np.max(predictions_array),
                                class_names[true_label]),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  true_label = true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

# %% [markdown]
# Verify predictions

# %%
i = 0
plt.figure(figsize=(6,3))
plt.subplot(1,2,1)
plot_image(i, predictions[i], test_labels, test_images)
plt.subplot(1,2,2)
plot_value_array(i, predictions[i],  test_labels)
plt.show()

# %%
i = 12
plt.figure(figsize=(6,3))
plt.subplot(1,2,1)
plot_image(i, predictions[i], test_labels, test_images)
plt.subplot(1,2,2)
plot_value_array(i, predictions[i],  test_labels)
plt.show()

# %%
# Plot the first X test images, their predicted labels, and the true labels.
# Color correct predictions in blue and incorrect predictions in red.
num_rows = 5
num_cols = 3
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i, predictions[i], test_labels, test_images)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i, predictions[i], test_labels)
plt.tight_layout()
plt.show()

# %% [markdown]
# Use the trained model

# %%
# Grab an image from the test dataset.
img = test_images[1]

print(img.shape)
# Out:
# (28, 28)

# %%
# Add the image to a batch where it's the only member.
img = (np.expand_dims(img,0))

print(img.shape)
# Out:
# (1, 28, 28)

# %%
predictions_single = probability_model.predict(img)

print(predictions_single)
# Out:
# 1/1 [==============================] - 0s 25ms/step
# [[1.20976438e-04 8.19468937e-14 8.76452029e-01 2.15188889e-09
#   1.20902605e-01 1.68373277e-13 2.52443086e-03 1.21981957e-18
#   3.31930230e-13 7.85625938e-15]]

# %%
plot_value_array(1, predictions_single[0], test_labels)
_ = plt.xticks(range(10), class_names, rotation=45)
plt.show()

# %%
np.argmax(predictions_single[0])
# Out:
# 2
